# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.numbeo.com/cost-of-living/in/Aachen"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")

# %%
soup.
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n\n<meta property="og:title" content="Cost of Living in Aachen" />\n<meta property="og:description" content="Average prices of more than 40 products and services in Aachen, GermanyMar 2023. Prices of restaurants, food, transportation, utilities and housing are included. " />\n<meta property="og:type" content="website"/>\n<meta property="og:url" content="https://www.numbeo.com/cost-of-living/in/Aachen"/>\n<link rel="alternate" hreflang="en" href="https://www.numbeo.com/cost-of-living/in/Aachen" />\n<link rel="alternate" hreflang="de" href="https://de.numbeo.com/lebenshaltungskosten/stadt/Aachen" />\n<link rel="alternate" hreflang="pt" href="https://pt.numbeo.com/custo-de-vida/cidade/Aachen" />\n<link rel="alternate" hreflang="it" href="https://it.numbeo.com/costo-della-vita/citt%C3%A0/Aquisgrana" />\n<link rel="alternate" hreflang="fr" href="https://fr.numbeo.com/co%C3%B
# ...
